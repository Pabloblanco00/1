# %% [markdown]
# <a href="https://colab.research.google.com/github/Pabloblanco00/1/blob/main/Act5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = 'https://raw.githubusercontent.com/Pabloblanco00/1/main/antropometria-dataset-1.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
data.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

plt.figure(figsize=(8, 5))
sns.boxplot(x='sexo', y='edad', data=data)
plt.title('Boxplot de edad')
plt.xlabel('Sexo')
plt.ylabel('edad')
plt.show()

# %%
ndata = pd.pivot_table(data,
                              index = 'desc_ent',
                              columns= 'sexo',
                              aggfunc = 'median',
                              margins = True,
                              values = 'edad')
ndata = ndata.drop('All')
ndata
# Out:
# sexo                                1     2   All
# desc_ent
# AGUASCALIENTES                   28.5  28.0  28.0
# BAJA CALIFORNIA                  25.0  29.5  27.0
# BAJA CALIFORNIA SUR              29.0  29.0  29.0
# CAMPECHE                         33.0  30.0  31.0
# CHIAPAS                          24.0  28.0  27.5
# CHIHUAHUA                        32.0  34.0  33.0
# COAHUILA DE ZARAGOZA             26.0  33.0  30.0
# COLIMA                           30.0  34.0  33.0
# DISTRITO FEDERAL                 26.0  26.0  26.0
# DURANGO                          30.0  35.0  33.0
# GUANAJUATO                       22.0  34.0  29.5
# GUERRERO                         27.0  37.0  34.0
# HIDALGO                          26.0  35.0  33.0
# JALISCO                          30.5  36.0  34.0
# MEXICO                           20.0  28.0  23.0
# MICHOACAN DE OCAMPO              31.0  32.0  32.0
# MORELOS                          29.0  35.0  33.0
# NAYARIT                          30.0  35.0  33.0
# ...

# %%
mdata = ndata[2]
plt.figure(figsize=(8, 5))
plt.boxplot(mdata.dropna(), vert=False)
plt.title('Boxplot edad')
plt.ylabel('edad')
plt.grid(True)
plt.show()

# %%
ndata = pd.pivot_table(data,
                              index = 'desc_ent',
                              columns= 'sexo',
                              aggfunc = 'median',
                              margins = True,
                              values = 'peso')
ndata = ndata.drop('All')
ndata
# Out:
# sexo                                   1        2      All
# desc_ent
# AGUASCALIENTES                   69.9500  63.7000  66.6000
# BAJA CALIFORNIA                  70.6500  64.2000  67.9500
# BAJA CALIFORNIA SUR              76.6500  68.5500  71.2500
# CAMPECHE                         67.3500  62.3750  64.3500
# CHIAPAS                          59.2000  56.0250  57.2000
# CHIHUAHUA                        69.3000  64.6250  66.3000
# COAHUILA DE ZARAGOZA             68.3000  67.3000  67.7000
# COLIMA                           71.7000  66.0000  68.9000
# DISTRITO FEDERAL                 69.0000  61.4500  64.0250
# DURANGO                          70.3500  62.5000  65.7000
# GUANAJUATO                       65.0625  60.3250  62.0625
# GUERRERO                         60.5000  57.2000  57.9500
# HIDALGO                          63.3000  57.9000  59.7000
# JALISCO                          65.5875  63.3500  64.2000
# MEXICO                           62.4500  56.9500  59.5500
# ...

# %%
ndata = data[data['sexo'] == 1].groupby('desc_ent')['cadera'].median()

plt.figure(figsize=(8, 5))
ndata.plot(kind='line', marker='o', color='red')
plt.title('Line Plot Cadera for Sex 1')
plt.xlabel('Region')
plt.ylabel('Median Cadera (cm)')
plt.xticks(rotation=90)
plt.grid(True)

plt.show()

# %%
ndata = data[data['sexo'] == 2].groupby('desc_ent')['ropa'].sum()
tdata = ndata.sort_values(ascending=False).head(10)

plt.figure(figsize=(8, 5))
tdata.plot(kind='barh', color='green')
plt.title(' ropa for Sex 1')
plt.xlabel('Sum of Ropa')
plt.ylabel('Region')
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(data['talla'], bins=25, color='gray', edgecolor='black')
plt.title('Histogram of Talla')
plt.xlabel('Talla (cm)')
plt.ylabel('Frequency')
plt.grid(True)

plt.show()
